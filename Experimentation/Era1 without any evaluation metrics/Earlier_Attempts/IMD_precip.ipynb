# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model
from IPython.display import Image
import cv2 as cv
import os
import pydot
from tensorflow.keras.layers import Dropout
# Out:
# 2024-08-12 18:27:34.903269: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-12 18:27:34.903398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-12 18:27:35.019157: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
Image(filename='/kaggle/input/imd-architecture/Architecture_IMD.png')

# %%
import pickle
SR_file_path = '/kaggle/input/imd-final-dataset/SR_Data_final/SR_Data_final.pkl'
LR_file_path = '/kaggle/input/imd-final-dataset/LR_Data_final/LR_Data_final.pkl'
with open(SR_file_path, 'rb') as file:
    SR_data = pickle.load(file)
with open(LR_file_path, 'rb') as file:
    LR_data = pickle.load(file)

# %%
import pickle
SR_pic_file_path = '/kaggle/input/imd-lr-sr/data/data.pkl'
LR_pic_file_path = '/kaggle/input/imd-lr-sr/LR_data/LR_data.pkl'
with open(SR_pic_file_path, 'rb') as file:
    SR_pic_data = pickle.load(file)
with open(LR_pic_file_path, 'rb') as file:
    LR_pic_data = pickle.load(file)

# %%
for key in SR_data:
    rainfall_array_final = [] 
    for j in range(SR_data[key].shape[0]):
        k = SR_data[key][j, 1:]
        nan_column = np.full((k.shape[0], 1), -1)
        modified_row = np.hstack((k, nan_column))
        rainfall_array_final.append(modified_row)
    rainfall_array_final = np.array(rainfall_array_final)
    SR_data[key] = rainfall_array_final
for key in SR_pic_data:
    rainfall_array_final = [] 
    for j in range(SR_pic_data[key].shape[0]):
        k = SR_pic_data[key][j, 1:]
        nan_column = np.full((k.shape[0], 1), -1)
        modified_row = np.hstack((k, nan_column))
        rainfall_array_final.append(modified_row)
    rainfall_array_final = np.array(rainfall_array_final)
    SR_pic_data[key] = rainfall_array_final

# %%
print(SR_data[1901][0].shape)
print(SR_pic_data[1901][0].shape)
# Out:
# (128, 136)
# (128, 136)

# %%
SR_rainfall = SR_pic_data[1901][0]
lat25 = np.load('/kaggle/input/coordinates-imd/0.25lat.npy')
lon25 = np.load('/kaggle/input/coordinates-imd/0.25lon.npy')
print(len(lat25),len(lon25))
plt.figure(figsize=(10, 6))
X_SR, Y_SR = np.meshgrid(lon25, lat25)
plt.contourf(X_SR, Y_SR, SR_rainfall, cmap='Blues')
plt.colorbar(label='Rainfall (mm/day)')
plt.title(f'Rainfall')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# 128 136

# %%
for key in LR_data:
    final_rainfall_array = []
    for j in range(LR_data[key].shape[0]):
        k = LR_data[key][j][1:][:]
        k = np.delete(k,0,1)
        final_rainfall_array.append(k)
    LR_data[key] = final_rainfall_array
for key in LR_pic_data:
    final_rainfall_array = []
    for j in range(LR_pic_data[key].shape[0]):
        k = LR_pic_data[key][j][1:][:]
        k = np.delete(k, 0, 1)
        final_rainfall_array.append(k)
    LR_pic_data[key] = final_rainfall_array

# %%
print(LR_data[1901][0].shape)
# Out:
# (32, 34)

# %%
LR_rainfall = LR_pic_data[1901][0]
lat1 = np.load('/kaggle/input/coordinates-imd/1lat.npy')
lon1 = np.load('/kaggle/input/coordinates-imd/1lon.npy')
print(len(lat1),len(lon1))
print(LR_rainfall.shape)
plt.figure(figsize=(10, 6))
X_LR, Y_LR = np.meshgrid(lon1, lat1)
plt.contourf(X_LR, Y_LR, LR_rainfall, cmap='Blues')
plt.colorbar(label='Rainfall (mm/day)')
plt.title(f'Rainfall')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# 32 34
# (32, 34)

# %% [markdown]
# # Generator

# %%
class DepthToSpaceLayer(tf.keras.layers.Layer):
    def __init__(self, block_size, **kwargs):
        super(DepthToSpaceLayer, self).__init__(**kwargs)
        self.block_size = block_size

    def call(self, inputs):
        return tf.nn.depth_to_space(inputs, self.block_size)
def residual_block_gen(ch=64, k_s=3, st=1):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(ch, k_s, strides=(st, st), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(),
        tf.keras.layers.Conv2D(ch, k_s, strides=(st, st), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(),
    ])
    return model
def Upsample_block(x, ch=256, k_s=3, st=1):
    x = tf.keras.layers.Conv2D(ch, k_s, strides=(st, st), padding='same')(x)
    x = DepthToSpaceLayer(block_size=2)(x)  # Use the custom layer for depth_to_space
    x = tf.keras.layers.LeakyReLU()(x)
    return x
input_lr = tf.keras.layers.Input(shape=(None, None, 1))  # Input shape with 1 channel for grayscale
input_conv = tf.keras.layers.Conv2D(64, 9, padding='same')(input_lr)
input_conv = tf.keras.layers.LeakyReLU()(input_conv)
Generator = input_conv
for _ in range(5):
    res_output = residual_block_gen()(Generator)
    Generator = tf.keras.layers.Add()([Generator, res_output])
Generator = tf.keras.layers.Conv2D(64, 9, padding='same')(Generator)
Generator = tf.keras.layers.BatchNormalization()(Generator)

Generator = tf.keras.layers.Add()([Generator, input_conv])

Generator = Upsample_block(Generator)  
Generator = Upsample_block(Generator) 

# Output layer with 1 channel since the output should be grayscale
output_sr = tf.keras.layers.Conv2D(1, 9, activation='tanh', padding='same')(Generator)

Generator = tf.keras.models.Model(input_lr, output_sr)

# %%
tf.keras.utils.plot_model(Generator, show_shapes=True, to_file='model.png')

# %%
Generator.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 1)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      5,248 │ input_layer[0][0] │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0]      │
# │ (LeakyReLU)         │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, None,      │     74,368 │ leaky_re_lu[0][0] │
# │ (Sequential)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, None,      │          0 │ leaky_re_lu[0][0… │
# │                     │ None, 64)         │            │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, None,      │     74,368 │ add[0][0]         │
# │ (Sequential)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, None,      │          0 │ add[0][0],        │
# │                     │ None, 64)         │            │ sequential_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, None,      │     74,368 │ add_1[0][0]       │
# │ (Sequential)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, None,      │          0 │ add_1[0][0],      │
# │                     │ None, 64)         │            │ sequential_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_3        │ (None, None,      │     74,368 │ add_2[0][0]       │
# │ (Sequential)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, None,      │          0 │ add_2[0][0],      │
# │                     │ None, 64)         │            │ sequential_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_4        │ (None, None,      │     74,368 │ add_3[0][0]       │
# │ (Sequential)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, None,      │          0 │ add_3[0][0],      │
# │                     │ None, 64)         │            │ sequential_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │    331,840 │ add_4[0][0]       │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, None,      │          0 │ batch_normalizat… │
# │                     │ None, 64)         │            │ leaky_re_lu[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │    147,712 │ add_5[0][0]       │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depth_to_space_lay… │ (None, None,      │          0 │ conv2d_12[0][0]   │
# │ (DepthToSpaceLayer) │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, None,      │          0 │ depth_to_space_l… │
# │ (LeakyReLU)         │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │    147,712 │ leaky_re_lu_11[0… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depth_to_space_lay… │ (None, None,      │          0 │ conv2d_13[0][0]   │
# │ (DepthToSpaceLayer) │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, None,      │          0 │ depth_to_space_l… │
# │ (LeakyReLU)         │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      5,185 │ leaky_re_lu_12[0… │
# │                     │ None, 1)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,009,793 (3.85 MB)
#  Trainable params: 1,008,385 (3.85 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %% [markdown]
# # Discriminator (Critic)

# %%
def residual_block_disc(ch=64, k_s=3, st=1):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(ch, k_s, strides=(st, st), padding='same',
                               kernel_initializer=tf.keras.initializers.HeNormal()),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        # Optional: Move BatchNormalization after activation or remove
        # tf.keras.layers.BatchNormalization(),
    ])
    return model

input_lr = tf.keras.layers.Input(shape=(128, 136, 1))
input_conv = tf.keras.layers.Conv2D(64, 3, padding='same', kernel_initializer=tf.keras.initializers.HeNormal())(input_lr)
input_conv = tf.keras.layers.LeakyReLU(alpha=0.2)(input_conv)

channel_nums = [64, 128, 128, 256, 256, 512, 512]
stride_sizes = [2, 1, 2, 1, 2, 1, 2]

disc = input_conv
for x in range(7):
    disc = residual_block_disc(ch=channel_nums[x], st=stride_sizes[x])(disc)

disc = tf.keras.layers.Flatten()(disc)
disc = tf.keras.layers.Dense(1024, kernel_initializer=tf.keras.initializers.HeNormal())(disc)
disc = tf.keras.layers.LeakyReLU(alpha=0.2)(disc)
disc_output = tf.keras.layers.Dense(1)(disc)  # Linear activation for WGAN

discriminator = tf.keras.models.Model(input_lr, disc_output)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
tf.keras.utils.plot_model(discriminator,show_shapes=True)

# %%
discriminator.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 128, 136, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 128, 136, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_13 (LeakyReLU)      │ (None, 128, 136, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_5 (Sequential)       │ (None, 64, 68, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_6 (Sequential)       │ (None, 64, 68, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_7 (Sequential)       │ (None, 32, 34, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ (None, 32, 34, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_9 (Sequential)       │ (None, 16, 17, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_10 (Sequential)      │ (None, 16, 17, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_11 (Sequential)      │ (None, 8, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    37,749,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_21 (LeakyReLU)      │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,435,009 (161.88 MB)
#  Trainable params: 42,435,009 (161.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Feature Extractor

# %%
from keras.models import load_model
model = load_model('/kaggle/input/rainfall_feature_extractor/tensorflow2/default/1/final.h5')

# %%
feature_extractor = Model(inputs=model.input, outputs=model.layers[-2].output)
feature_extractor.summary()
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 136, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 136, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 136, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128, 136, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 136, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 136, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128, 136, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 128, 136, 3)    │         1,731 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128, 136, 3)    │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128, 136, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,851,919 (64.28 MB)
#  Trainable params: 2,136,969 (8.15 MB)
#  Non-trainable params: 14,714,950 (56.13 MB)

# %%
def gradient_penalty(discriminator, real_images, fake_images):
    batch_size = tf.shape(real_images)[0]
    alpha = tf.random.uniform([batch_size, 1, 1, 1], 0.0, 1.0)
    interpolated_images = alpha * real_images + (1 - alpha) * fake_images

    with tf.GradientTape() as tape:
        tape.watch(interpolated_images)
        predictions = discriminator(interpolated_images)

    gradients = tape.gradient(predictions, [interpolated_images])[0]

    # Clip gradients to avoid extreme values
    gradients = tf.clip_by_value(gradients, -1.0, 1.0)

    gradients_sqr = tf.square(gradients)
    gradients_sqr_sum = tf.reduce_sum(gradients_sqr, axis=[1, 2, 3])

    # Increase epsilon to ensure stability
    gradient_l2_norm = tf.sqrt(gradients_sqr_sum + 1e-8)

    gradient_penalty = tf.reduce_mean((gradient_l2_norm - 1.0) ** 2)

    return gradient_penalty

# %%
def discriminator_loss(real_output, fake_output, gp, lambda_gp=10):
    return tf.reduce_mean(fake_output) - tf.reduce_mean(real_output) + lambda_gp * gp

# %%
def generator_loss(fake_output, real_images, fake_images, feature_extractor):
    # Adversarial loss
    adv_loss = -tf.reduce_mean(fake_output)

    # Feature matching loss (using the pre-trained feature extractor)
    real_features = feature_extractor(real_images)
    fake_features = feature_extractor(fake_images)
    feature_loss = tf.reduce_mean(tf.abs(real_features - fake_features))

    return adv_loss + feature_loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4, beta_1=0.0, beta_2=0.9)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4, beta_1=0.0, beta_2=0.9)

def train_step(SR_images, LR_images, batch_size, noise_dim):
    noise = tf.random.normal([batch_size, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        fake_images = Generator(LR_images, training=True)

        real_output = discriminator(SR_images, training=True)
        fake_output = discriminator(fake_images, training=True)

        # Gradient penalty
        gp = gradient_penalty(discriminator, SR_images, fake_images)

        # Losses
        gen_loss = generator_loss(fake_output, SR_images, fake_images, feature_extractor)
        disc_loss = discriminator_loss(real_output, fake_output, gp)

    # Calculate gradients
    gradients_of_generator = gen_tape.gradient(gen_loss, Generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    # Apply gradients
    generator_optimizer.apply_gradients(zip(gradients_of_generator, Generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# Training loop
def train(SR_data, LR_data, epochs, noise_dim, batch_size):
    for epoch in range(epochs):
        for i in range(123):
            lr = np.array(LR_data[1901+i][:32]).reshape((batch_size, 32, 34, 1)) 
            sr = np.array(SR_data[1901+i][:32]).reshape((batch_size, 128, 136, 1))
            gen_loss, disc_loss = train_step(sr, lr, batch_size, noise_dim)
        
        print(f'Epoch {epoch+1}, Generator Loss: {gen_loss.numpy()}, Discriminator Loss: {disc_loss.numpy()}')
        sr_pic = np.array(SR_pic_data[2000][0])
        lr_pic = np.array(LR_data[2000][:32]).reshape((32,32, 34, 1))
        generated = np.array(Generator(lr_pic))
        plt.figure(figsize=(14, 6))
        plt.subplot(1, 2, 1)
        X_SR, Y_SR = np.meshgrid(lon25, lat25)
        plt.contourf(X_SR, Y_SR, generated[0].reshape(128, 136), cmap='Blues')
        plt.colorbar(label='Rainfall (mm/day)')
        plt.title('Generated Rainfall data')
        plt.xlabel('Longitude')
        plt.ylabel('Latitude')
        plt.subplot(1, 2, 2)
        plt.contourf(X_SR, Y_SR, sr_pic, cmap='Blues')
        plt.colorbar(label='Rainfall (mm/day)')
        plt.title('Actual Rainfall data')
        plt.xlabel('Longitude')
        plt.ylabel('Latitude')
        plt.show()

# %%
train(SR_data,LR_data, epochs=100, noise_dim=100, batch_size=32)
# Out:
# Epoch 1, Generator Loss: -851281510400.0, Discriminator Loss: -52483170762752.0
# Epoch 2, Generator Loss: -1685778857984.0, Discriminator Loss: -598822325583872.0
# Epoch 3, Generator Loss: 50878451023872.0, Discriminator Loss: -3736868776574976.0
# Epoch 4, Generator Loss: -312067693215744.0, Discriminator Loss: -1.6420657478762496e+16
# Epoch 5, Generator Loss: -1004928260636672.0, Discriminator Loss: -5.740450565377229e+16
# Epoch 6, Generator Loss: -3522069140602880.0, Discriminator Loss: -1.759366694913966e+17
# Epoch 7, Generator Loss: -2.09452670124032e+16, Discriminator Loss: -4.742893902065828e+17
# Epoch 8, Generator Loss: -2.759545693457613e+16, Discriminator Loss: -1.1160943934266409e+18
# Epoch 9, Generator Loss: -1.2282470877206938e+17, Discriminator Loss: -2.520094669635846e+18
# Epoch 10, Generator Loss: -1.7142176551010304e+17, Discriminator Loss: -5.273811370918281e+18
# Epoch 11, Generator Loss: -7.224982990214922e+17, Discriminator Loss: -1.0244117950151786e+19
# Epoch 12, Generator Loss: -7.392426241619395e+17, Discriminator Loss: -1.991930020558065e+19
# Epoch 13, Generator Loss: -2.647849124690395e+18, Discriminator Loss: -3.481738589380595e+19
# Epoch 14, Generator Loss: -2.043672982785622e+18, Discriminator Loss: -6.386109989071828e+19
# Epoch 15, Generator Loss: -8.782454130221253e+18, Discriminator Loss: -1.024300018663099e+20
# Epoch 16, Generator Loss: -2.4877037717641232e+19, Discriminator Loss: -1.6326430017738873e+20
# Epoch 17, Generator Loss: nan, Discriminator Loss: nan
# /opt/conda/lib/python3.10/site-packages/matplotlib/contour.py:1454: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /opt/conda/lib/python3.10/site-packages/matplotlib/contour.py:1455: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# Epoch 18, Generator Loss: nan, Discriminator Loss: nan
# Epoch 19, Generator Loss: nan, Discriminator Loss: nan
# Epoch 20, Generator Loss: nan, Discriminator Loss: nan
# Epoch 21, Generator Loss: nan, Discriminator Loss: nan
# Epoch 22, Generator Loss: nan, Discriminator Loss: nan

# %%
# lr = np.array(LR_data[2000][:32]).reshape((32,32, 34))
# generated = np.array(Generator(lr))
# print(generated[0].shape)

# %%
# plt.figure(figsize=(10, 6))
# X_SR, Y_SR = np.meshgrid(lon25, lat25)
# plt.contourf(X_SR, Y_SR, generated[0].reshape(128,136), cmap='Blues')
# plt.colorbar(label='Rainfall (mm/day)')
# plt.title(f'Rainfall')
# plt.xlabel('Longitude')
# plt.ylabel('Latitude')
# plt.show()
